# %%
# %%capture
# Tjek om vi kører i Google Colab
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    # 1. Clone hele dit repository for at få adgang til datafiler og billeder
    # !git clone https://github.com/mpsteenstrup/simuleringerOgFordeliger.git
    # %cd simuleringerOgFordeliger
    
    # 2. Installer nødvendige pakker fra din requirements.txt
    # (Hvis du har en requirements.txt i dit repo)
    # !pip install -r requirements.txt

# %%
from vpython import *

# %%
sphere(pos=vec(-2,2,0), radius=0.5, color=color.red)
box(pos=vec(0,2,0), length=1, height=1, width=1, color=color.orange)

# %%
from jupyturtle import *
import random

# %%
['DEFAULT_DRAW_HEIGHT', 'DEFAULT_DRAW_WIDTH', 'PEN_COLOR', 'PEN_WIDTH', 'Path', 'Point', 'Turtle', 'back', 'bk', 'draw', 'fd', 'forward', 'get_turtle', 'hide', 'jp', 'jump_to', 'jumpto', 'jupyturtle', 'left', 'lt', 'make_turtle', 'move_to', 'moveto', 'mv', 'no_pen', 'no_update', 'pd', 'pen_down', 'pen_up', 'pendown', 'penup', 'pu', 'right', 'rt', 'set_color', 'set_default', 'set_heading', 'set_width', 'show', 'show_SVG', 'toggle_pen']

# %%
t = make_turtle(width=400, height=400, delay=0)
#t = Turtle(delay=0)
t.pen_down()
i = 0
n=1000
s=1
while i<n:
  #t.left(360*random.random())
  t.left(random.uniform(0,360))
  t.forward(s)
  i+=1
d = (t.x**2+t.y**2)**0.5
print(d)
print(s*n**0.5)
# Out:
# <svg width="400" height="400" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 200,200 199.5,199.1 199.6,200.1 199.8,199.1 200.2,198.2 201,198.8 200.1,198.4 200.6,199.3 200.7,200.3 199.9,200.9 200.6,201.6 200.1,202.5 200.6,203.3 201.2,204.1 200.8,203.2 200.2,204 201.1,204.4 200.5,205.1 199.5,205.2 200.4,204.8 199.7,205.5 198.8,205.2 199.4,204.4 200.3,204.7 201.2,204.3 201.9,203.6 202.3,202.7 203.2,203 204.2,202.7 203.6,201.9 204.6,201.7 204.4,202.7 203.5,202.2 202.7,202.8 201.7,202.5 202.7,202.9 202.2,202 203,201.4 203.9,201.8 202.9,201.7 201.9,201.7 202.5,201 203.4,201.5 202.4,201.7 202.7,202.6 202.6,203.6 203.2,204.4 202.5,203.6 201.6,203.4 200.7,203 199.7,203 200.5,203.6 201,202.7 201.8,202.1 201.2,201.3 200.2,201.7 200.4,202.7 199.7,203.4 198.9,202.9 198.1,203.6 197.9,204.5 198.8,204.8 198.1,205.4 197.6,206.3 197.1,207.2 196.5,206.4 196.7,205.4 196.9,206.4 197.4,207.2 196.4,207.5 195.6,208.1 194.6,208.1 193.6,208.3 192.7,208.7 191.8,209.1 191.7,210.1 192.7,210.4 193.7,210.1 192.9,209.5 192.1,210.1 191.6,210.9 191,211.7 192,211.5 192.9,
.7,214.1 189.7,214 189.4,215 188.6,214.4 188.3,215.4 187.3,215.2 188.3,214.9 187.5,215.5 187.6,216.5 188.6,216.4 189.6,216.2 189.5,217.2 190.4,217.4 191.4,217.2 190.6,216.6 191.1,217.4 191.6,218.3 192.6,218.4 193.1,217.5 193.8,218.1 192.9,217.7 192.1,218.3 191.2,217.9 192.2,217.7 192.9,218.4 193.7,219 192.9,218.4 191.9,218.3 190.9,218.4 190,217.9 189.3,218.6 189.4,217.6 189.8,218.5 190.8,218.3 191.4,217.5 192.4,217.7 192.5,218.7 191.6,219.3 191,218.5 191.3,217.6 192.3,217.8 192.9,218.6 191.9,218.7 192.1,217.7 191.5,216.8 191.3,215.9 190.9,214.9 191.6,215.6 192.3,214.8 193,215.6 192,215.7 192.4,216.6 193.4,216.4 194.2,217.1 195.2,217.1 194.9,218.1 195.9,218 196.2,219 196.3,218 195.7,217.2 195.4,218.2 196.2,218.8 196.2,217.8 197,217.1 197.9,217.6 196.9,217.8 197.9,217.5 197.7,216.5 198.4,217.2 198.7,216 ...
# 310.34526049398886
# 31.622776601683793

# %%
t = Turtle(delay=0)
t.hide()  # Gør det hurtigere
t.pen_up()     # Hvis du bare vil have slutdata uden streger

def sim(n):
    for _ in range(n):
        t.left(random.uniform(0, 360))
        t.forward(4)
    return t.x

x = 0
m=10
n=10
for i in range(m):
    x+=sim(n)
print(x/m)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.3,71" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.8,67" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147,65.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 149.1,69.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 146,71.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 149.9,70.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 153.8,71.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 157.1,68.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160.4,71.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 161.5,67.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 157.7,66.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 155.3,69.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 155.3,65.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 158.9,63.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 156,61" />'
#
# <path stroke="#663399" stroke-width="2" d="M 154,57.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.2,56.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 149.4,52.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.2,56.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 151.3,52.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147.6,50.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150,47.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 146.9,50.1" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144,52.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147.9,54" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144.6,56.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 143.8,52.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 145.1,48.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 143.5,44.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147.2,43.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 143.7,41.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144,37.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 142.5,41.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144.3,37.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 146.4,41" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.1,39.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147.1,42.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144.8,38.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 141.4,36.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144.6,34.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 145,30.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147,33.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147,29.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 148.3,33.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 146.4,37.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.3,36.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150,40.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 153.8,41.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 153.3,45.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.2,48.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147.6,51.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144.5,48.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 143,52.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 143.1,56.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 140.1,58.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 139.9,54.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 143.1,57.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 141.7,53.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 145.7,53.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 149.6,53.1" />'
#
# <path stroke="#663399" stroke-width="2" d="M 148,56.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.9,59.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150.3,63.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 147.5,60.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 144.6,63.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 140.6,62.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 138.3,65.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 134.5,67" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130.8,68.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 134.5,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 131.3,67.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 131.1,71.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130.4,75.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 132.9,72.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130.3,75.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 127.9,72.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130.3,69.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 127.7,66.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 124,67.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 120.5,69.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 118,72.7" />'
#
# <path stroke="#663399" stroke-width="2" d="M 114.1,73.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 110.3,72.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 112,68.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 112.3,64.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 115.6,62.4" />'
#
# <path stroke="#663399" stroke-width="2" d="M 114.8,66.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 112.6,62.9" />'
#
# <path stroke="#663399" stroke-width="2" d="M 115.9,65.1" />'
#
# <path stroke="#663399" stroke-width="2" d="M 113.1,62.3" />'
#
# <path stroke="#663399" stroke-width="2" d="M 116,59.5" />'
#
# <path stroke="#663399" stroke-width="2" d="M 116.3,55.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 116.3,51.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 112.6,53" />'
#
# <path stroke="#663399" stroke-width="2" d="M 110.1,49.8" />'
#
# <path stroke="#663399" stroke-width="2" d="M 109,53.6" />'
#
# <path stroke="#663399" stroke-width="2" d="M 105.1,54.2" />'
#
# <path stroke="#663399" stroke-width="2" d="M 109.1,54.1" />'
#
# <path stroke="#663399" stroke-width="2" d="M 112.9,55.1" />'
#
# <path stroke="#663399" stroke-width="2" d="M 109,56" />'
#
# </svg>
# 138.14905115449852
